# %%
#池谷关
import numpy as np
import math
import matplotlib.pyplot as plt
lgr = np.array([1.031,
0.983,
0.883,
0.857,
0.777,
0.692,
0.663,
0.47,
0.434,
0.271,
0.006,
0.106,
0.272,
0.317,
0.358,
0.397,
0.505,
0.539,
0.571,
0.722,
0.778,
0.935,
0.959,
1.008,
1.193,
1.237,
1.258,
1.301,
1.385,
1.621
])

length = len(lgr)
for x in range(0,length):
    lgr[x] = math.log10(lgr[x])

m = np.array([7.3,
6.3,
6.2,
6.1,
5,
4.8,
4.8,
3,
3,
1,
-8,
-3,
1,
1.8,
2.3,
3,
4.1,
4.2,
4.6,
5.5,
6,
6.3,
6.5,
6.5,
7.5,
7.3,
7.5,
7.7,
8,
9.5
])

lgd = np.array([1.451,
1.395,
1.283,
1.255,
1.175,
1.099,
1.075,
0.954,
0.939,
0.906,
1.002,
1.028,
1.04,
1.042,
1.044,
1.046,
1.05,
1.051,
1.051,
1.053,
1.053,
1.051,
1.051,
1.05,
1.046,
1.047,
1.047,
1.048,
1.052,
1.091
])

for x in range(0,length):
    lgd[x] = math.log10(lgd[x])



A = np.vstack([lgr, np.ones(len(lgr))]).T

k, M = np.linalg.lstsq(A,m - 5 * lgd,rcond=None)[0]
#k斜率、M5lgd截距
print(np.linalg.lstsq(A,m - 5 * lgd,rcond=None))
plt.scatter(lgr,m - 5 * lgd)
x = np.array([min(lgr),max(lgr)])
y = k * x + M
plt.plot(x,y)
plt.show()
# Out:
# (array([7.36264047, 6.15695077]), array([18.34449418]), 2, array([5.6731418 , 2.37109559]))

# %%
#哈雷
import numpy as np
import math
import matplotlib.pyplot as plt
lgr = np.array([2.101,
2.033,
1.921,
1.779,
1.707,
1.619,
1.515,
1.257,
1.211,
0.966,
0.863,
0.706,
0.623,
0.66,
0.69,
0.761,
0.787,
0.814,
0.856,
0.929,
1.004,
1.127,
1.219,
1.326,
1.402,
1.448,
1.582,
1.671,
1.743,
1.815,
1.886,
2.04,
2.04,
2.122,
2.23,
2.257,
2.27
])

length = len(lgr)
for x in range(0,length):
    lgr[x] = math.log10(lgr[x])

m = np.array([11.5,
9.3,
10.6,
7.2,
7.6,
6.1,
6.8,
5.4,
5.1,
4.8,
4.4,
5,
3.5,
4.1,
3,
2.8,
3.6,
2.8,
3,
3.8,
3.5,
3.8,
4,
4.1,
3,
2.9,
3.3,
4.8,
4.2,
5.2,
5.7,
6.4,
7,
7,
7.3,
7.6,
8
])

lgd = np.array([1.536,
1.378,
1.132,
0.856,
0.74,
0.636,
0.584,
0.767,
0.826,
1.157,
1.291,
1.472,
1.548,
1.415,
1.365,
1.248,
1.205,
1.161,
1.092,
0.973,
0.851,
0.66,
0.538,
0.454,
0.458,
0.489,
0.673,
0.838,
0.988,
1.144,
1.305,
1.663,
1.663,
1.859,
2.117,
2.181,
2.213
])

for x in range(0,length):
    lgd[x] = math.log10(lgd[x])



A = np.vstack([lgr, np.ones(len(lgr))]).T

k, M = np.linalg.lstsq(A,m - 5 * lgd,rcond=None)[0]
#k斜率、M5lgd截距
np.linalg.lstsq(A,m - 5 * lgd,rcond=None)

plt.scatter(lgr,m - 5 * lgd)
x = np.array([min(lgr),max(lgr)])
y = k * x + M
plt.plot(x,y)
plt.show()

# %%
#百武
import numpy as np
import math

lgr = np.array([1.725,
1.673,
1.621,
1.567,
1.513,
1.458,
1.402,
1.345,
1.287,
1.228,
1.168,
1.107,
1.045,
0.981,
0.915,
0.849,
0.78,
0.71,
0.637,
0.563,
0.488,
0.412,
0.337,
0.273,
0.233
])

length = len(lgr)
for x in range(0,length):
    lgr[x] = math.log10(lgr[x])

m = np.array([7.9,
7.6,
7.2,
6.8,
6.5,
6.2,
5.6,
5.5,
4.6,
3.2,
2.4,
1.5,
-1.2,
0.8,
1.8,
2.3,
2.8,
2.6,
2.4,
2.2,
2,
1.7,
1.8,
2.5,
2.8
])

lgd = np.array([1.222,
1.121,
1.02,
0.919,
0.819,
0.718,
0.619,
0.519,
0.421,
0.325,
0.232,
0.149,
0.102,
0.135,
0.214,
0.304,
0.389,
0.494,
0.591,
0.689,
0.787,
0.887,
0.986,
1.082,
1.166
])

for x in range(0,length):
    lgd[x] = math.log10(lgd[x])



A = np.vstack([lgr, np.ones(len(lgr))]).T

k, M = np.linalg.lstsq(A,m - 5 * lgd,rcond=None)[0]
#k斜率、M5lgd截距
print(np.linalg.lstsq(A,m - 5 * lgd,rcond=None))
plt.scatter(lgr,m - 5 * lgd)
x = np.array([min(lgr),max(lgr)])
y = k * x + M
plt.plot(x,y)
plt.show()
# Out:
# (array([6.93793673, 5.39189107]), array([9.48308549]), 2, array([5.00802228, 1.24881577]))

# %%
#麦克诺特
import numpy as np
import math

lgr = np.array([2.821,
2.488,
2.118,
0.174,
0.295,
0.354,
0.384,
0.499,
0.608,
0.661,
0.834,
0.928,
1.061,
1.104,
1.188,
1.484,
1.54,
1.842,
2.434,
2.567,
2.909,
2.951
])

length = len(lgr)
for x in range(0,length):
    lgr[x] = math.log10(lgr[x])

m = np.array([13.9,
13.6,
11.3,
-5.2,
-3,
-1,
0,
2,
2.4,
3,
4.4,
3.8,
5,
4.9,
5.5,
6.5,
7.1,
8.3,
9.4,
10.5,
10.1,
10.3
])

lgd = np.array([2.53,
2.6,
2.601,
0.828,
0.856,
0.896,
0.917,
1.008,
1.096,
1.138,
1.272,
1.341,
1.433,
1.461,
1.513,
1.673,
1.7,
1.825,
2.061,
2.134,
2.395,
2.436
])

for x in range(0,length):
    lgd[x] = math.log10(lgd[x])



A = np.vstack([lgr, np.ones(len(lgr))]).T

k, M = np.linalg.lstsq(A,m - 5 * lgd,rcond=None)[0]
#k斜率、M5lgd截距
print(np.linalg.lstsq(A,m - 5 * lgd,rcond=None))
plt.scatter(lgr,m - 5 * lgd)
x = np.array([min(lgr),max(lgr)])
y = k * x + M
plt.plot(x,y)
plt.show()
# Out:
# (array([11.58861144,  4.312127  ]), array([24.99722487]), 2, array([4.69315922, 1.65751429]))

# %%
#2007
import numpy as np
import math

lgr = np.array([2.821,
2.488,
2.118,
0.174,
0.295,
0.354,
0.384,
0.499,
0.608,
0.661,
0.834,
0.928,
1.061,
1.104,
1.188,
1.484,
1.54,
1.842,
2.434,
2.567,
2.909,
2.951
])

length = len(lgr)
for x in range(0,length):
    lgr[x] = math.log10(lgr[x])

m = np.array([13.9,
13.6,
11.3,
-5.2,
-3,
-1,
0,
2,
2.4,
3,
4.4,
3.8,
5,
4.9,
5.5,
6.5,
7.1,
8.3,
9.4,
10.5,
10.1,
10.3
])

lgd = np.array([2.53,
2.6,
2.601,
0.828,
0.856,
0.896,
0.917,
1.008,
1.096,
1.138,
1.272,
1.341,
1.433,
1.461,
1.513,
1.673,
1.7,
1.825,
2.061,
2.134,
2.395,
2.436
])

for x in range(0,length):
    lgd[x] = math.log10(lgd[x])



A = np.vstack([lgr, np.ones(len(lgr))]).T

k, M = np.linalg.lstsq(A,m - 5 * lgd,rcond=None)[0]
#k斜率、M5lgd截距
print(np.linalg.lstsq(A,m - 5 * lgd,rcond=None))
plt.scatter(lgr,m - 5 * lgd)
x = np.linspace(lgr[0],lgr[-1],30)
y = k * x + M
plt.plot(x,y)
plt.show()
